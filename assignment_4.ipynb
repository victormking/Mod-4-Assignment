# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pandas as pd
import numpy as np
import datetime

# %%
# Choose a league, season, and 4 teams within the league. For the given season, collect the roster table from sports reference for ALL 4 teams. This should result in you having 4 different CSVs(one for each team)

# In your notebook file, read all 4 CSVs in, with the index being the player name.

# Concatenate the 4 tables into 1 all-inclusive table.

# %%
nyk_1970_roster = pd.read_csv("data/nyk1970roster.csv", index_col='Player')
nyk_1970_roster
# Out:
#                   No. Pos      Ht   Wt        Birth Date Unnamed: 6 Exp  \
# Player
# Dick Barnett       12  SG   4-Jun  190    October 2 1936         us   9
# Nate Bowman        17   C  10-Jun  230     March 19 1943         us   3
# Bill Bradley       24  SF   5-Jun  205      July 28 1943         us   2
# Dave DeBusschere   22  PF   6-Jun  220   October 16 1940         us   7
# Walt Frazier       10  PG   4-Jun  200     March 29 1945         us   2
# Bill Hosket        20  PF   8-Jun  225  December 20 1946         us   1
# Don May             5  SF   4-Jun  200    January 3 1946         us   1
# Willis Reed        19   C  10-Jun  235      June 25 1942         us   5
# Mike Riordan        6  SG   4-Jun  200       July 9 1945         us   1
# Cazzie Russell     33  SF   5-Jun  218       June 7 1944         us   3
# Dave Stallworth     9  SF   7-Jun  200  December 20 1941         us   2
# John Warren        16  SG   3-Jun  180       July 7 1947         us   R
#
# ...

# %%
sonics_1970_roster = pd.read_csv("data/sonics1970roster.csv", index_col='Player')
sonics_1970_roster
# Out:
#                No. Pos     Ht   Wt         Birth Date Unnamed: 6 Exp  \
# Player
# Lucius Allen    42  PG  2-Jun  175  September 26 1947         us   R
# Bob Boozer      20  PF  8-Jun  215      April 26 1937         us   9
# Barry Clemens   43  SF  6-Jun  210         May 1 1943         us   4
# Al Hairston     25  SG  1-Jun  170   December 11 1945        NaN   1
# Art Harris      12  SG  4-Jun  185    January 13 1947        NaN   1
# Joe Kennedy     34  SF  6-Jun  210    January 12 1947        NaN   1
# Tom Meschery    14  SF  6-Jun  215    October 26 1938         cn   8
# Erwin Mueller   24  PF  8-Jun  230      March 12 1944         us   3
# Dorie Murrey    41   C  8-Jun  215   September 7 1943        NaN   3
# Bob Rule        45   C  9-Jun  220       June 29 1944         us   2
# Dick Snyder     10  SG  5-Jun  207    February 1 1944         us   3
# Rod Thorn       44  SG  4-Jun  195        May 23 1941         us   6
# ...

# %%
bullets_1970_roster = pd.read_csv("data/bullets1970roster.csv", index_col='Player')
bullets_1970_roster
# Out:
#                 No. Pos      Ht   Wt        Birth Date Unnamed: 6 Exp  \
# Player
# Fred Carter       3  SG   3-Jun  185  February 14 1945         us   R
# Mike Davis       13  SG   3-Jun  185      July 26 1946         us   R
# Leroy Ellis      23   C  10-Jun  210     March 10 1940         us   7
# Brian Heaney     11   G   2-Jun  180  September 3 1946        NaN   R
# Gus Johnson      25  PF   6-Jun  230  December 13 1938         us   6
# Kevin Loughery   22  SG   3-Jun  190     March 28 1940         us   7
# Ed Manning       35  PF   7-Jun  210    January 2 1944         us   2
# Jack Marin       24  SF   7-Jun  200   October 12 1944         us   3
# Eddie Miles      15  SG   4-Jun  195       July 5 1940         us   6
# Earl Monroe      10  PG   3-Jun  185  November 21 1944         us   2
# Bob Quick        15  SF   5-Jun  215      March 5 1946         us   1
# Ray Scott        31  PF   9-Jun  215      July 12 1938         us   8
# ...

# %%
royals_1970_roster = pd.read_csv("data/royals1970roster.csv", index_col='Player')
royals_1970_roster
# Out:
#                   No. Pos      Ht   Wt        Birth Date Unnamed: 6 Exp  \
# Player
# Wally Anderzunas   21  SF   7-Jun  220   January 11 1946        NaN   R
# Bob Cousy          19  PG   1-Jun  175     August 9 1928         us  13
# Connie Dierking    24   C   9-Jun  222    October 2 1936         us   8
# Fred Foster        15  SF   5-Jun  210     March 18 1946         us   1
# Herm Gilliam       30  SG   3-Jun  190        May 5 1946         us   R
# Johnny Green       20  PF   5-Jun  200   December 8 1933         us  10
# Jim King           17  PG   2-Jun  175   February 7 1941         us   6
# Jerry Lucas        16  PF   8-Jun  230     March 30 1940         us   6
# Luther Rackley     22   C  10-Jun  220      June 11 1946         us   R
# Oscar Robertson    14  PG   5-Jun  205  November 24 1938         us   9
# Adrian Smith       10  SG   1-Jun  180    October 5 1936         us   8
# Bill Turner        13  PF   7-Jun  220  February 18 1944        NaN   2
# ...

# %%
# Write the concatenated table to CSV. (Note: the index SHOULD be included)

# %%
nba_rosters_1970 = pd.concat([nyk_1970_roster,sonics_1970_roster,bullets_1970_roster,royals_1970_roster])
nba_rosters_1970.to_csv("data/nba_rosters_1970.csv")
nba_rosters_1970
# Out:
#                   No. Pos      Ht   Wt         Birth Date Unnamed: 6 Exp  \
# Player
# Dick Barnett       12  SG   4-Jun  190     October 2 1936         us   9
# Nate Bowman        17   C  10-Jun  230      March 19 1943         us   3
# Bill Bradley       24  SF   5-Jun  205       July 28 1943         us   2
# Dave DeBusschere   22  PF   6-Jun  220    October 16 1940         us   7
# Walt Frazier       10  PG   4-Jun  200      March 29 1945         us   2
# Bill Hosket        20  PF   8-Jun  225   December 20 1946         us   1
# Don May             5  SF   4-Jun  200     January 3 1946         us   1
# Willis Reed        19   C  10-Jun  235       June 25 1942         us   5
# Mike Riordan        6  SG   4-Jun  200        July 9 1945         us   1
# Cazzie Russell     33  SF   5-Jun  218        June 7 1944         us   3
# Dave Stallworth     9  SF   7-Jun  200   December 20 1941         us   2
# John Warren        16  SG   3-Jun  180        July 7 1947         us   R
# ...
